# %%
files = ['chinese_food.json', 'indian_food.json', 'japanese_food.json', 'muslim_food.json', 'western_food.json']
result_files = ['clean_' + text for text in files]

# %%
def sanitizerJSON(path_to_file, path_to_result, selection=None):

    import json 
    with open(path_to_file, encoding='utf-8') as file:
        f = json.load(file)
        print("Keys:", f.keys())
        data = f.get('data')
        data_1 = data[0]

        # Set Up
        if selection:
            result = {}
            for index, d in enumerate(data):
                    result.update({index: {}})
                    for k in selection:
                        result.get(index).update({k: data[index].get(k)})
        else: 
            dict_of_keys = {}

            for index, key in enumerate(data_1.keys()):
                dict_of_keys.update({index: key})

            # Get Information on Structure of data
            print("\nLength of keys:", len(data_1.keys()))
            print("\n".join([" - ".join((str(i), j )) for i, j in enumerate(data_1.keys())]))

            # Select Data to Show
            data_to_extract = [int(i) for i in input("Enter index of data you want").split(',')]

            # Extract Data
            result = {}
            for index, d in enumerate(data):
                result.update({index: {}})
                for k in data_to_extract:
                    key = dict_of_keys.get(k)
                    result.get(index).update({key: data[index].get(key)})

        # Write to JSON
        with open(path_to_result, 'w', encoding='utf-8') as result_file:
            r = json.dumps(result)
            result_file.write(r)
        return result

for i in range(len(files)):
    sanitizerJSON(files[i], result_files[i], ['thumbnails', 'images', 'businessHour', 'body', 'uuid', 'rating', 'contact','companyDisplayName', 'officialWebsite', 'officialEmail', 'cuisine', 'pricing', 'description', 'address', 'name', 'location'])
# Out:
# Keys: dict_keys(['status', 'data', 'nextToken'])
#
# Length of keys: 32
# 0 - metadata
# 1 - thumbnails
# 2 - images
# 3 - businessHour
# 4 - notes
# 5 - temporarilyClosed
# 6 - body
# 7 - nearestMrtStation
# 8 - dataset
# 9 - uuid
# 10 - supportedLanguage
# 11 - reviews
# 12 - rating
# 13 - contact
# 14 - categoryDescription
# 15 - companyDisplayName
# 16 - amenities
# 17 - officialWebsite
# 18 - videos
# 19 - documents
# 20 - officialEmail
# 21 - cuisine
# 22 - pricing
# 23 - staYear
# 24 - tags
# 25 - source
# 26 - description
# 27 - group
# 28 - address
# 29 - name
# 30 - location
# 31 - type
# Enter index of data you want1,2,3,6,9,12,13,15,17,20,22,26,28,29,30,31
# Keys: dict_keys(['status', 'data', 'nextToken'])
#
# Length of keys: 32
# 0 - metadata
# 1 - body
# 2 - rating
# 3 - uuid
# 4 - companyDisplayName
# 5 - categoryDescription
# 6 - amenities
# 7 - thumbnails
# 8 - images
# 9 - businessHour
# 10 - notes
# 11 - temporarilyClosed
# 12 - supportedLanguage
# 13 - dataset
# 14 - reviews
# 15 - contact
# 16 - nearestMrtStation
# 17 - officialWebsite
# 18 - videos
# 19 - documents
# 20 - officialEmail
# 21 - cuisine
# 22 - pricing
# 23 - staYear
# 24 - tags
# 25 - source
# 26 - description
# 27 - group
# 28 - address
# 29 - name
# 30 - location
# 31 - type
# Enter index of data you want7, 8
# Keys: dict_keys(['status', 'data', 'nextToken'])
#
# Length of keys: 32
# 0 - uuid
# 1 - companyDisplayName
# 2 - thumbnails
# 3 - images
# 4 - businessHour
# 5 - notes
# 6 - rating
# 7 - temporarilyClosed
# 8 - supportedLanguage
# 9 - categoryDescription
# 10 - metadata
# 11 - amenities
# 12 - reviews
# 13 - contact
# 14 - nearestMrtStation
# 15 - body
# 16 - dataset
# 17 - officialEmail
# 18 - staYear
# 19 - cuisine
# 20 - pricing
# 21 - officialWebsite
# 22 - videos
# 23 - documents
# 24 - tags
# 25 - source
# 26 - description
# 27 - group
# 28 - address
# 29 - name
# 30 - location
# 31 - type
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\DARRYL~1\AppData\Local\Temp/ipykernel_15108/4212227212.py in <module>
#      36
#      37 for i in range(len(files)):
# ---> 38     sanitizerJSON(files[i], result_files[i])
#
# C:\Users\DARRYL~1\AppData\Local\Temp/ipykernel_15108/4212227212.py in sanitizerJSON(path_to_file, path_to_result)
#      19
#      20         # Select Data to Show
# ---> 21         data_to_extract = [int(i) for i in input("Enter index of data you want").split(',')]
#      22
#      23         # Extract Data
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
